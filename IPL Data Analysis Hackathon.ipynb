# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"deliveries.csv")

# %%
df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df1 = pd.read_csv(r"matches.csv")

# %%
df1
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
data = pd.merge(df1,df, left_on='id', right_on='match_id',how='inner')

# %%
data
# Out:
#            id  season       city        date                team1  \
# 0           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 2           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 3           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 4           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# ...       ...     ...        ...         ...                  ...
# 179073  11415    2019  Hyderabad    12/05/19       Mumbai Indians
# 179074  11415    2019  Hyderabad    12/05/19       Mumbai Indians
# 179075  11415    2019  Hyderabad    12/05/19       Mumbai Indians
# 179076  11415    2019  Hyderabad    12/05/19       Mumbai Indians
# 179077  11415    2019  Hyderabad    12/05/19       Mumbai Indians
#
#                               team2                  toss_winner  \
# 0       Royal Challengers Bangalore  Royal Challengers Bangalore
# ...

# %%
df.isna().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
df1.isna().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
city_season_counts = df1['city'].value_counts()
most_seasons_count = city_season_counts.max()
print(f"The city that hosted the most seasons is '{most_seasons_city}' with {most_seasons_count} seasons.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 city_season_counts = df1['city'].value_counts()
#       2 most_seasons_count = city_season_counts.max()
# ----> 3 print(f"The city that hosted the most seasons is '{most_seasons_city}' with {most_seasons_count} seasons.")
#
# NameError: name 'most_seasons_city' is not defined

# %%
df1['year'] = pd.to_datetime(df1['date']).dt.year
matches_per_year = df1['year'].value_counts()
most_matches_count = matches_per_year.max()
print(f"The year with the most number of matches played is {most_matches_year} with {most_matches_count} matches.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 matches_per_year = df1['year'].value_counts()
#       3 most_matches_count = matches_per_year.max()
# ----> 4 print(f"The year with the most number of matches played is {most_matches_year} with {most_matches_count} matches.")
#
# NameError: name 'most_matches_year' is not defined

# %%
mi_matches_2011 = df1[((df1['team1'] == 'Mumbai Indians') | (df1['team2'] == 'Mumbai Indians')) & (df1['season'] == 2011)]

mi_wins_2011 = mi_matches_2011[mi_matches_2011['winner'] == 'Mumbai Indians'].shape[0]

print(f"Mumbai Indians had {mi_wins_2011} wins in the 2011 season.")
# Out:
# Mumbai Indians had 10 wins in the 2011 season.

# %%
sns.countplot(x='toss_decision', data=df1)
plt.title('Distribution of Toss Decisions')
plt.xlabel('Toss Decision')
plt.ylabel('Count')
plt.show()

# %%
toss_decision_counts = df1['toss_decision'].value_counts()
total_toss_decisions = len(df1['toss_decision'])
percentage_bat = (toss_decision_counts['bat'] / total_toss_decisions) * 100
percentage_field = (toss_decision_counts['field'] / total_toss_decisions) * 100
print(f"Percentage of 'bat' decisions: {percentage_bat:.1f}%")
print(f"Percentage of 'field' decisions: {percentage_field:.1f}%")
# Out:
# Percentage of 'bat' decisions: 38.8%
# Percentage of 'field' decisions: 61.2%

# %%
field_wins = df1[(df1['toss_winner'] == df1['winner']) & (df1['toss_decision'] == 'field')]
bat_wins = df1[(df1['toss_winner'] == df1['winner']) & (df1['toss_decision'] == 'bat')]
if len(field_wins) > len(bat_wins):
    print("A) Teams winning tosses and electing field first have won more number of matches.")
elif len(bat_wins) > len(field_wins):
    print("B) Teams winning tosses and electing bat first have won more number of matches.")
else:
    print("C) Both A and B")
# Out:
# A) Teams winning tosses and electing field first have won more number of matches.

# %%
batting_second_wins = df1[df1['win_by_wickets'] > 0]
batting_second_wins_per_year = batting_second_wins['season'].value_counts()
print(f" {', '.join(map(str, years_with_more_batting_second_wins))}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 batting_second_wins = df1[df1['win_by_wickets'] > 0]
#       2 batting_second_wins_per_year = batting_second_wins['season'].value_counts()
# ----> 3 print(f" {', '.join(map(str, years_with_more_batting_second_wins))}")
#
# NameError: name 'years_with_more_batting_second_wins' is not defined

# %%
top_10_batsmen = df.groupby('batsman')['total_runs'].sum().nlargest(10).index
df_top_10 = df[df['batsman'].isin(top_10_batsmen)]
plt.figure(figsize=(12, 6))
sns.lineplot(x='match_id', y='total_runs', hue='batsman', data=df_top_10)
plt.title('Consistency of Top 10 Batsmen')
plt.xlabel('Match ID')
plt.ylabel('Total Runs')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='batsman', y='total_runs', data=df_top_10, ci=None)
plt.title('Total Runs of Top 10 Batsmen')
plt.xlabel('Batsman')
plt.ylabel('Total Runs')
plt.show()
# Out:
# C:\Users\p7522\AppData\Local\Temp\ipykernel_19768\759309428.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='batsman', y='total_runs', data=df_top_10, ci=None)

# %%
df_2019 = df1[df1['season'] == 2019]
df_2019['total_runs_boundary'] = (df_2019['4s'] * 4) + (df_2019['6s'] * 6)
highest_scorer_boundary = df_2019.groupby('batsman')['total_runs_boundary'].sum().idxmax()
highest_runs_boundary = df_2019.groupby('batsman')['total_runs_boundary'].sum().max()
print(f" {highest_scorer_boundary} with {highest_runs_boundary} runs.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '4s'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
bowler_wickets = df['player_dismissed'].groupby(df['bowler']).count()
most_wickets = bowler_wickets.max()
print(f" {most_wickets_bowler} with {most_wickets} wickets.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 bowler_wickets = df['player_dismissed'].groupby(df['bowler']).count()
#       2 most_wickets = bowler_wickets.max()
# ----> 3 print(f" {most_wickets_bowler} with {most_wickets} wickets.")
#
# NameError: name 'most_wickets_bowler' is not defined

# %%
kohli_2016_data = df[(df['batsman'] == 'Virat Kohli') & (df['match_id'].between(577, 636))]
total_runs_kohli = kohli_2016_data['total_runs'].sum()
total_balls_faced_kohli = kohli_2016_data.shape[0]
print(f"Virat Kohli's strike rate in 2016: {strike_rate_kohli:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2 total_runs_kohli = kohli_2016_data['total_runs'].sum()
#       3 total_balls_faced_kohli = kohli_2016_data.shape[0]
# ----> 4 print(f"Virat Kohli's strike rate in 2016: {strike_rate_kohli:.2f}")
#
# NameError: name 'strike_rate_kohli' is not defined

# %%
strike_rate_kohli = (total_runs_kohli / total_balls_faced_kohli) * 100

# %%
bowler_extras = df.groupby('bowler')['extra_runs'].sum()
max_extras_bowlers = bowler_extras[bowler_extras == bowler_extras.max()].index
max_extras_count = bowler_extras.max()
print(f"The bowler(s) with the maximum number of extras is/are {', '.join(max_extras_bowlers)} with {max_extras_count} extras.")
# Out:
# The bowler(s) with the maximum number of extras is/are SL Malinga with 293 extras.

# %%
venue_counts = df1['venue'].value_counts()
most_matches_venue = venue_counts.idxmax()
most_matches_count = venue_counts.max()
print(f"The venue that has hosted the most number of IPL matches is {most_matches_venue} with {most_matches_count} matches.")
# Out:
# The venue that has hosted the most number of IPL matches is Eden Gardens with 77 matches.

# %%
match_condition = ((df1['team1'] == 'Sunrisers Hyderabad') | (df1['team2'] == 'Sunrisers Hyderabad')) & ((df1['team1'] == 'Royal Challengers Bangalore') | (df1['team2'] == 'Royal Challengers Bangalore')) & (df1['season'] == 2017)
player_of_match = df1.loc[match_condition, 'player_of_match'].iloc[0]
print(f"In the 2017 match between Sunrisers Hyderabad and Royal Challengers Bangalore, the Player of the Match was {player_of_match}.")
# Out:
# In the 2017 match between Sunrisers Hyderabad and Royal Challengers Bangalore, the Player of the Match was Yuvraj Singh.

# %%
run_outs = df[df['dismissal_kind'] == 'run out']
run_out_counts = run_outs.groupby('batsman')['dismissal_kind'].count()
top_three_run_outs = run_out_counts.nlargest(3)
print("Top three batsmen with the most run-outs:")
print(top_three_run_outs)
# Out:
# Top three batsmen with the most run-outs:
# batsman
# MS Dhoni      21
# RG Sharma     17
# KD Karthik    16
# Name: dismissal_kind, dtype: int64

# %%
kohli_vs_bumrah = df[(df['batsman'] == 'V Kohli') & (df['bowler'] == 'JJ Bumrah')]
total_runs_kohli_vs_bumrah = kohli_vs_bumrah['total_runs'].sum()
print(f"Total runs scored by Virat Kohli against JJ Bumrah is {total_runs_kohli_vs_bumrah}.")
# Out:
# Total runs scored by Virat Kohli against JJ Bumrah is 114.

# %%
caught_and_bowled = df[df['dismissal_kind'] == 'caught and bowled']
caught_and_bowled_counts = caught_and_bowled.groupby('batsman')['dismissal_kind'].count()
max_caught_and_bowled_player = caught_and_bowled_counts.idxmax()
max_caught_and_bowled_count = caught_and_bowled_counts.max()
print(f"The player dismissed the maximum number of times via caught and bowled is {max_caught_and_bowled_player} with {max_caught_and_bowled_count} dismissals.")
# Out:
# The player dismissed the maximum number of times via caught and bowled is SK Raina with 7 dismissals.

# %%
sixes_counts = df[df['batsman_runs'] == 6].groupby('batsman')['batsman_runs'].count()
highest_sixes_player = sixes_counts.idxmax()
highest_sixes_count = sixes_counts.max()
print(f"The player with the highest number of sixes is {highest_sixes_player} with {highest_sixes_count} sixes.")
# Out:
# The player with the highest number of sixes is CH Gayle with 327 sixes.
